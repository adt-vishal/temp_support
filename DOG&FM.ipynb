# %% [markdown]
# ### Decision Option Generator (DOG)

# %%
from DOG.dog_modular import DecisionOptionGenerator
from FrequencyMapping.freq_mapping import FrequencyMapping

import configparser
config = configparser.ConfigParser()
config.read('config.ini')
DOG_CONFIG_FILE = config['DEFAULT']['DOG_CONFIG']
FM_CONFIG_FILE =  config['DEFAULT']['FM_CONFIG']

import warnings
warnings.filterwarnings('ignore')
# Out:
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/xgboost/compat.py:31: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# #### 1. DOG

# %%
DOG = DecisionOptionGenerator(DOG_CONFIG_FILE)    
DOG.save_outputs()
# Out:
# Reading Config files and Input Schema...
# Top Churners: 3562
# Premium Churners: 5011
# High CLTV Churners: 5389
# Slow Churners: 0
# TOP Upsell Candidates 1934
# Medium Premium Upsell:  13448
# High Cross-sell 6907
# Default Candidates: 6724
# rmse: 1164.217544044068
# Feature Beta Coefficients: [7.03344 5.3194  3.44856 4.88406 6.69697]
# Index(['OfferID', 'OfferName', 'Offer_Category', 'Price', 'Feature1',
#        'Feature2', 'Feature3', 'Feature4', 'Feature5', 'Validity (Days)',
#        'Offer Description', 'Objective'],
#       dtype='object')
# -up sell -------------
#     pf_customer_id  OfferID  Est_to_Curr_Rev_Ratio  offer_rank
# 57               4       58              22.146538         1.0
# 42               4       43              20.040991         2.0
# 38               4       39              19.621916         3.0
# ----------------------
#    pf_customer_id                                       OfferName  OfferID  \
# ...

# %% [markdown]
# #### 2. Frequencu Mapping for Communications

# %%
FM = FrequencyMapping(FM_CONFIG_FILE)
FM.map_frequency()
# Out:
# Reading Config files and Input Schema...
# Frequency of communication output:
#     pf_customer_id  Segment         pf_name  \
# 0              39      4.0    Regina Davis
# 1              72      1.0    Angela Duffy
# 2             129      1.0   Frank Sanders
# 3             160      6.0    Andrew Moyer
# 4             317      1.0      Bruce Rice
# 5             321      1.0  Teresa Johnson
# 6             429      1.0      Terry Meza
# 7             430      6.0    John Johnson
# 8             441      5.0       Marc Rice
# 9             486      6.0     Tyler Brown
#
#                              pf_email      pf_phone  \
# 0       Regina.Davis@santos-baker.com  2.925292e+09
# 1              Angela.Duffy@lopez.com  5.512331e+09
# 2    Frank.Sanders@collins-little.com  3.418543e+09
# 3  Andrew.Moyer@humphrey-woodard.info  3.571925e+09
# 4                 Bruce.Rice@reed.com  1.463127e+09
# 5            Teresa.Johnson@riley.com  2.825141e+09
# ...
