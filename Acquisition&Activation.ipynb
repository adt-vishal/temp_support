# %% [markdown]
# ## Customer Acquisition

# %%
from BehavioralModels.CustomerAcquisition.acq_seg import Acquisition_segmentation
from BehavioralModels.CustomerAcquisition.acq_opt_offer import Acquisition_Offer_Reco
from BehavioralModels.CustomerAcquisition.acq_freq_mapping import AcquisitionFrequencyMapping
from BehavioralModels.CustomerAcquisition.acq_cdna_data import Acquisiton_CDNA
from BehavioralModels.CustomerAcquisition.acq_mult_campaign import Acquisition_Mult_Campaign
from BehavioralModels.CustomerAcquisition.helper import Preprocess_data

# %%
import configparser
import yaml
config = configparser.ConfigParser()
config.read('config.ini')
CA_CONFIG = config['DEFAULT']['CA_CONFIG']

# %%
print('Performing Acquisition Customer Segmentation')
Cus_seg = Acquisition_segmentation(CA_CONFIG)
Cus_seg.load_data()
Cus_seg.choose_k()
Cus_seg.clust()
Cus_seg.save()
# Out:
# Performing Acquisition Customer Segmentation
# {'acq_input_path': 'Inputs', 'acq_test_path': 'Inputs', 'acq_output_path': 'Outputs', 'acq_input_filename': 'acq_seg_train.csv', 'acq_test_filename': 'leads.csv', 'acq_output_filename': 'train_output.csv', 'acq_test_output_filename': 'test_output.csv', 'categorical_columns': ['Cust_Sex', 'Cust_City', 'Cust_Region', 'Cust_Graduated', 'Cust_Profession', 'Cust_Marital_Status'], 'numerical_columns': ['Cust_Age', 'Cust_Income', 'Cust_Work_Experience', 'Cust_Family_Size'], 'cat_index': [1, 2, 3, 5, 7, 8], 'test_col_to_drop': ['Lead_ID', 'pf_name', 'pf_email', 'pf_phone', 'pf_address'], 'model_name': 'NA'}
# Data loaded successfully!
# Scaling Completed
# Encoding Completed, choosing optimal number of clusters
# Number of clusters: 4
# Fitting k-prototype clustering on train_data.csv
# Clustering completed
# Saving outputs
# Segmented leads data:
#     Lead_ID  Cust_Age Cust_Sex Cust_City   Cust_Region  Cust_Income  \
# 0        1        22   Female     Lagos        Africa         3288
# 1        2        23   Female     Lagos        Africa         7121
# 2        3        20   Female     Tokyo  Asia Pacific        11332
# 3        4        29   Female    London        Europe        15838
# 4        5        27     Male     Tokyo  Asia Pacific         2123
# 5        6        22     Male     Lagos        Africa         1347
# 6        7        18   Female     Cairo        Africa          817
# 7        8        30   Female     Lagos        Africa        16304
# 8        9        20   Female     Lagos        Africa         1918
# 9       10        20     Male     Tokyo  Asia Pacific        10467
#
#   Cust_Graduated  Cust_Work_Experience         Cust_Profession  \
# 0             No                     1  Professional/Technical
# 1            Yes                     1                   Owner
# 2            Yes                     4                 Retired
# 3             No                     2                Military
# 4            Yes                     3                Business
# 5            Yes                     4         Sales/Marketing
# 6            Yes                     2               Homemaker
# 7             No                     3         Sales/Marketing
# 8            Yes                     3               Homemaker
# 9            Yes                     4         Sales/Marketing
#
#   Cust_Marital_Status  Cust_Family_Size  Clusters
# 0              Single                 5         2
# 1             Married                 4         1
# 2             Married                 5         3
# 3             Married                 2         1
# 4              Single                 6         1
# 5              Single                 2         1
# 6              Single                 6         2
# 7             Married                 4         2
# 8             Married                 4         3
# 9              Single                 2         1
# Outputs dumped to Outputs/Customer_Acquisition/Seg_Output

# %%
print('Allocating multiple campaigns to Acquisition Leads')
AMC = Acquisition_Mult_Campaign(CA_CONFIG)
AMC.load_data()
AMC.acq_neighbours()
# Out:
# Allocating multiple campaigns to Acquisition Leads
# {'acq_mult_campaign_input_path': 'Outputs/Customer_Acquisition/Seg_Output', 'acq_mult_campaign_mr_input_path': 'Inputs', 'acq_mult_campaign_output_path': 'Outputs/Customer_Acquisition', 'acq_mult_campaign_train_filename': 'train_output.csv', 'acq_mult_campaign_test_filename': 'test_output.csv', 'acq_mult_campaign_mr_filename': 'cust_offer_response_50k.csv', 'acq_mult_campaign_cdna_filename': 'cdna_individual_for_acq.csv', 'acq_mult_campaign_output_filename': 'candidature_allocation.csv', 'relevant_cols': ['pf_customer_id', 'Cust_Age', 'Cust_Income', 'Cust_Work_Experience', 'Cust_Family_Size', 'Clusters', 'Cust_cat'], 'num_cols': ['Cust_Age', 'Cust_Income', 'Cust_Work_Experience', 'Cust_Family_Size'], 'cluster_col': 'Clusters', 'cust_id_col': 'pf_customer_id', 'cdna_useful_cols': ['pf_customer_id', 'CLV_6M', 'predicted_upsell_flag']}
# Data Imported
# Saving outputs
# Acquisition leads candidature allocation output:
#     Lead_ID  Marketing_Response    CLV_6M  predicted_upsell_flag  \
# 0        1           26.269320  5172.290               0.341481
# 1        2           20.978908  4734.630               0.367390
# 2        3           18.175193  5734.110               0.372945
# 3        4           27.265097  4493.525               0.342683
# 4        5           21.946484  4436.810               0.320010
# 5        6           25.821779  4755.770               0.326563
# 6        7           30.208098  5172.290               0.316304
# 7        8           19.087385  5025.890               0.316722
# 8        9           19.038035  7044.230               0.363657
# 9       10           25.821779  4755.770               0.326563
#
#   Potential Candidature
# 0         Tough Targets
# 1      Inert Candidates
# 2      Inert Candidates
# 3         Tough Targets
# 4      Inert Candidates
# 5         Tough Targets
# 6         Tough Targets
# 7      Inert Candidates
# 8      Inert Candidates
# 9         Tough Targets
# Outputs dumped to Outputs/Customer_Acquisition/Candidature_Allocation

# %%
print('Performing Acquisition Customer Recommendation')
Cus_acq = Acquisition_Offer_Reco(CA_CONFIG)
Cus_acq.load_data()
Cus_acq.train_mab()
Cus_acq.save()
# Out:
# Performing Acquisition Customer Recommendation
# Reading Config files and Input Schema...
# Reading Config files and Input Schema...
#    pf_customer_id  Cust_Age  Cust_Income  Cust_Work_Experience  \
# 0              36  0.521739     0.447746              0.933333
# 1              54  0.695652     0.829039              0.800000
# 2              72  0.391304     0.514526              0.133333
# 3              86  0.239130     0.754717              0.800000
# 4              94  0.500000     0.851430              0.066667
#
#    Cust_Family_Size  Clusters  TxnId  OfferID  Marketing_Response  \
# 0          1.000000         0     91       12            0.161616
# 1          0.000000         2    875       11            0.666667
# 2          0.333333         2    861        8            0.747475
# 3          0.333333         2     99       13            0.868687
# 4          0.000000         2    894       20            0.656566
#
#    Cust_Sex_Male  Cust_Graduated_Yes  Cust_Marital_Status_Single
# 0              1                   1                           0
# 1              1                   1                           1
# 2              1                   1                           0
# 3              1                   1                           0
# 4              1                   1                           0
# Preprocessing Completed
#          12        11        8         13        20        9         15  \
# 0  0.161616  0.212121  0.858586  0.575758  0.050505  0.888889  0.323232
# 1  0.414141  0.666667  0.404040  0.616162  0.222222  0.393939  0.888889
# 2  0.525253  0.080808  0.747475  0.171717  0.131313  0.818182  0.454545
# 3  0.222222  0.010101  0.272727  0.868687  0.414141  0.101010  0.747475
# 4  0.525253  0.565657  1.677057  0.303030  0.656566  0.818182  0.000000
#
#          2         4         3         14        19        5         1   \
# 0  0.383838  0.868687  0.868687  0.292929  0.929293  0.555556  0.232323
# 1  0.020202  0.888889  0.464646  1.545744  0.555556  0.969697  0.858586
# 2  0.060606  0.444444  0.272727  0.464646  0.888889  0.000000  0.717172
# 3  0.383838  0.474747  0.565657  0.282828  0.212121  0.636364  0.909091
# 4  0.020202  0.080808  0.575758  0.464646  0.404040  0.373737  0.363636
#
#          16        18        17        7         10        6
# 0  0.828283  0.737374  0.494949  0.232323  0.333333  0.393939
# 1  0.010101  0.616162  0.282828  0.030303  0.404040  0.303030
# 2  0.626263  0.363636  0.020202  0.939394  0.777778  1.980087
# 3  0.595960  0.707071  0.020202  0.010101  0.575758  0.393939
# 4  0.626263  0.363636  0.808081  0.030303  0.030303  0.171717
# Optimal offers for each cluster:
# [11, 12, 7, 5, 1, 10, 9, 15, 20, 19, 6, 3, 2, 17, 16, 4, 14, 13, 8, 18] [17, 18, 12, 5, 7, 9, 16, 13, 11, 2, 4, 8, 20, 19, 10, 14, 15, 1, 3, 6] [17, 5, 2, 7, 20, 12, 16, 11, 6, 9, 8, 18, 15, 13, 4, 1, 10, 19, 14, 3]
# Saving output
# Optimal offer recommendations for acquisition leads:
#     Lead_ID  Cust_Age Cust_Sex    Cust_City   Cust_Region  Cust_Income  \
# 0       18        89     Male      Nairobi        Africa        12731
# 1       27        33     Male        Lagos        Africa         2199
# 2       28        78     Male         Rome        Europe         6448
# 3       29        70     Male      Bangkok  Asia Pacific        13015
# 4       51        61     Male        Tokyo  Asia Pacific         8445
# 5       54        50     Male  Los Angeles      Americas         9566
# 6       55        74     Male       Mumbai  Asia Pacific        17348
# 7       57        69     Male         Rome        Europe         1329
# 8       69        53     Male    Cape Town        Africa         9667
# 9       79        37     Male       London        Europe         7720
#
#   Cust_Graduated  Cust_Work_Experience         Cust_Profession  \
# 0             No                     4         Sales/Marketing
# 1            Yes                     5                 Retired
# 2            Yes                     7  Professional/Technical
# 3            Yes                     7  Professional/Technical
# 4             No                     4               Homemaker
# 5             No                     7                 Retired
# 6             No                     8  Professional/Technical
# 7            Yes                     8                   Owner
# 8            Yes                     6                   Owner
# 9             No                     4         Sales/Marketing
#
#   Cust_Marital_Status  ...  11th_best  12th_best  13th_best  14th_best  \
# 0             Married  ...          6          3          2         17
# 1              Single  ...          6          3          2         17
# 2              Single  ...          6          3          2         17
# 3              Single  ...          6          3          2         17
# 4              Single  ...          6          3          2         17
# 5              Single  ...          6          3          2         17
# 6             Married  ...          6          3          2         17
# 7              Single  ...          6          3          2         17
# 8              Single  ...          6          3          2         17
# 9              Single  ...          6          3          2         17
#
#    15th_best  16th_best  17th_best  18th_best  19th_best  20th_best
# 0         16          4         14         13          8         18
# 1         16          4         14         13          8         18
# 2         16          4         14         13          8         18
# 3         16          4         14         13          8         18
# 4         16          4         14         13          8         18
# 5         16          4         14         13          8         18
# 6         16          4         14         13          8         18
# 7         16          4         14         13          8         18
# 8         16          4         14         13          8         18
# 9         16          4         14         13          8         18
#
# [10 rows x 32 columns]
# Final recommendation output dumped to Outputs/Customer_Acquisition/Acquisition_Output

# %%
print('Performing Frequency Mapping')
acq_freq = AcquisitionFrequencyMapping(CA_CONFIG)
acq_freq.load_data()
acq_freq.freq_mapping()
acq_freq.output_for_act()
acq_freq.save()
# Out:
# Performing Frequency Mapping
# Reading Config files and Input Schema...
#          Date  Lead_ID  Offer_ID  Offer_Sent_Time  Ch1_Response  Ch2_Response  \
# 0  01-04-2022        1         5                1             0             0
# 1  01-04-2022        2         8                1             0             0
# 2  01-04-2022        3         5                1             0             0
# 3  01-04-2022        4         8                1             0             0
# 4  01-04-2022        5         8                1             0             0
#
#    Ch3_Response
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
#          Date  Lead_ID  Offer_ID  Offer_Sent_Time  Ch1_Response  Ch2_Response  \
# 0  01-04-2022        1         5                1             0             0
# 1  01-04-2022        2         8                1             0             0
# 2  01-04-2022        3         5                1             0             0
# 3  01-04-2022        4         8                1             0             0
# 4  01-04-2022        5         8                1             0             0
#
#    Ch3_Response Acquisition_Status
# 0             0       Not Acquired
# 1             0       Not Acquired
# 2             0       Not Acquired
# 3             0       Not Acquired
# 4             0       Not Acquired
# Acquired prospects:
#             Date  Lead_ID  Cust_ID  Offer_ID  Offer_Sent_Time  Ch1_Response  \
# 41   01-04-2022       42    60000         5                1             1
# 57   03-04-2022        8    60001         5                2             1
# 61   03-04-2022       12    60002         5                2             1
# 65   03-04-2022       16    60003         8                2             1
# 71   03-04-2022       22    60004        15                2             1
# 80   03-04-2022       31    60005         8                2             1
# 89   03-04-2022       40    60006         8                2             1
# 141  07-04-2022        1    60007         5                4             0
# 149  07-04-2022       10    60008         5                4             0
# 161  07-04-2022       25    60009         8                4             0
#
#      Ch2_Response  Ch3_Response Acquisition_Status Acquisition_Channel  \
# 41              0             0           Acquired           Channel_1
# 57              0             0           Acquired           Channel_1
# 61              0             0           Acquired           Channel_1
# 65              0             0           Acquired           Channel_1
# 71              0             0           Acquired           Channel_1
# 80              0             0           Acquired           Channel_1
# 89              0             0           Acquired           Channel_1
# 141             1             0           Acquired           Channel_2
# 149             1             0           Acquired           Channel_2
# 161             1             0           Acquired           Channel_2
#
#     Potential Candidature
# 41        Dormant Recruit
# 57        Dormant Recruit
# 61        Dormant Recruit
# 65        Dormant Recruit
# 71        Dormant Recruit
# 80        Dormant Recruit
# 89        Dormant Recruit
# 141       Dormant Recruit
# 149       Dormant Recruit
# 161       Dormant Recruit
# Outputs dumped to Outputs/Customer_Acquisition/Frequency_Mapping

# %%
print('Preparing Acquisition CDNA Data for DOG')
acq_cdna = Acquisiton_CDNA(CA_CONFIG)
acq_cdna.cdna_data_prep()
# Out:
# Preparing Acquisition CDNA Data for DOG
# Reading Config files and Input Schema...
#    pf_customer_id                pf_name  \
# 0             4.0           Eugene Gomez
# 1             6.0           Kevin Taylor
# 2             7.0       Andrew Armstrong
# 3            32.0  Christina Christensen
# 4            34.0     Robert Thompson MD
#
#                                  pf_email    pf_phone  \
# 0        Eugene.Gomez@robinson-flores.com  4879776796
# 1                  Kevin.Taylor@avila.com  2168094529
# 2             Andrew.Armstrong@bailey.com  1471015104
# 3          Christina.Christensen@mack.net  4615067320
# 4  Robert.Thompson MD@martin-reynolds.com  3036191736
#
#                                           pf_address  pf_age  pf_sex  \
# 0                   Unit 3229 Box 4821\nDPO AE 64834    42.0  Female
# 1           2668 Hooper Meadow\nCooperfurt, WI 26347    42.0    Male
# 2  473 Erickson Haven Apt. 222\nEast Haroldboroug...    40.0    Male
# 3                0575 Jason Trace\nDyerton, WV 40454    51.0    Male
# 4    64799 Paul Ways Apt. 862\nJeromemouth, MA 24922    27.0  Female
#
#   pf_region  pf_income           pf_occupation  ... CLE_45D   CLV_3M   CLV_6M  \
# 0        US   529908.0                   Owner  ...    1.94  3098.04  6104.93
# 1        US   812418.0  Professional/Technical  ...    2.57  3177.48  6261.48
# 2        US   549281.0  Professional/Technical  ...    1.38  1735.79  3420.53
# 3        US   985135.0                 Retired  ...    2.23  3790.65  7469.84
# 4        US   511967.0                 Retired  ...    1.81  2805.53  5528.56
#
#      CLV_9M   CLV_12M  win_back_score  \
# 0   9023.42  11856.09             0.0
# 1   9254.78  12160.11             0.0
# 2   5055.72   6642.82             0.0
# 3  11040.77  14506.74             0.0
# 4   8171.49  10736.69             0.0
#
#                                            OfferName  \
# 0  Get FREE 100MB, Recharge $50 and Get $45 back,...
# 1  5000 mins for 30 days , Get FREE 1G, WhatsApp ...
# 2  Get FREE 100MB, Recharge $50 and Get $45 back,...
# 3  Recharge $10 and Get $8 back, Recharge $5 and ...
# 4  Recharge $10 and Get $8 back, Combo 50MB & 5mi...
#
#                     ChannelName  \
# 0  Channel2, Channel1, Channel3
# 1  Channel2, Channel1, Channel3
# 2  Channel2, Channel1, Channel3
# 3  Channel2, Channel1, Channel3
# 4  Channel1, Channel3, Channel2
#
#                                  OfferCat_Rank_Score  Potential Candidature
# 0  [('OfferCat_2', 0.20342941528935296), ('OfferC...                Default
# 1  [('OfferCat_3', 0.21511505266185407), ('OfferC...  Medium Premium Upsell
# 2  [('OfferCat_1', 0.258950175990589), ('OfferCat...                Default
# 3  [('OfferCat_2', 0.2877469354329747), ('OfferCa...           Top Churners
# 4  [('OfferCat_2', 0.23297750597010453), ('OfferC...                Default
#
# [5 rows x 37 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                823 non-null    object
#  1   Lead_ID             823 non-null    int64
#  2   Offer_ID            823 non-null    int64
#  3   Offer_Sent_Time     823 non-null    int64
#  4   Ch1_Response        823 non-null    int64
#  5   Ch2_Response        823 non-null    int64
#  6   Ch3_Response        823 non-null    int64
#  7   Acquisition_Status  823 non-null    object
# dtypes: int64(6), object(2)
# memory usage: 51.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Offer_ID           20 non-null     int64
#  1   OfferName          20 non-null     object
#  2   Offer_Category     20 non-null     object
#  3   Price              20 non-null     int64
#  4   Feature1           20 non-null     int64
#  5   Feature2           20 non-null     int64
#  6   Feature3           20 non-null     int64
#  7   Feature4           20 non-null     int64
#  8   Feature5           20 non-null     int64
#  9   Validity (Days)    20 non-null     int64
#  10  Offer Description  20 non-null     object
#  11  Objective          20 non-null     object
# dtypes: int64(8), object(4)
# memory usage: 2.0+ KB
# None
# Final Customer DNA data output:
#     pf_customer_id        pf_name         pf_email   pf_phone  \
# 0           70000  Philip Duncan  Phi**@gmail.com  4852353.0
# 1           70001  Philip Duncan  Kat**@gmail.com  5674781.0
# 2           70002  Philip Duncan  Kat**@gmail.com  1816119.0
# 3           70003     Ryan Clark  Rob**@gmail.com  3183152.0
# 4           70004  Philip Duncan  Rya**@gmail.com  2038766.0
# 5           70005   Jamie Gregor  Kat**@gmail.com  4827482.0
# 6           70006    Mark Geller  Rya**@gmail.com  5287192.0
# 7           70007  Philip Duncan  Rya**@gmail.com  1896534.0
# 8           70008     Ryan Clark  Kat**@gmail.com  4696824.0
# 9           70009      Ted Mosby  Kat**@gmail.com  3628716.0
#
#                                           pf_address  pf_age  pf_sex  \
# 0   Flat No. 100, Mariners Apartments, GK2,New De...      22  Female
# 1               7292 Dictum Av.,San Antonio MI 47096      23  Female
# 2  Villa 440, 26th Street, Rowdah District, Abu D...      20  Female
# 3                70 Cliff Avenue,New London CT 06320      29  Female
# 4                104 Thomaston Road,Preston CT 06365      27    Male
# 5  Villa 440, 26th Street, Rowdah District, Abu D...      22    Male
# 6   318, C - Wing, Suyog Co.Housing Society Ltd, ...      18  Female
# 7  Villa 440, 26th Street, Rowdah District, Abu D...      30  Female
# 8       935-9940 Tortor. Street, Santa Rosa MN 98804      20  Female
# 9                70 Cliff Avenue,New London CT 06320      20    Male
#
#       pf_region  pf_income           pf_occupation  ... CLE_45D  CLV_3M  \
# 0        Africa       3288  Professional/Technical  ...      NA      NA
# 1        Africa       7121                   Owner  ...      NA      NA
# 2  Asia Pacific      11332                 Retired  ...      NA      NA
# 3        Europe      15838                Military  ...      NA      NA
# 4  Asia Pacific       2123                Business  ...      NA      NA
# 5        Africa       1347         Sales/Marketing  ...      NA      NA
# 6        Africa        817               Homemaker  ...      NA      NA
# 7        Africa      16304         Sales/Marketing  ...      NA      NA
# 8        Africa       1918               Homemaker  ...      NA      NA
# 9  Asia Pacific      10467         Sales/Marketing  ...      NA      NA
#
#   CLV_6M CLV_9M CLV_12M win_back_score  \
# 0     NA     NA      NA             NA
# 1     NA     NA      NA             NA
# 2     NA     NA      NA             NA
# 3     NA     NA      NA             NA
# 4     NA     NA      NA             NA
# 5     NA     NA      NA             NA
# 6     NA     NA      NA             NA
# 7     NA     NA      NA             NA
# 8     NA     NA      NA             NA
# 9     NA     NA      NA             NA
#
#                                            OfferName ChannelName  \
# 0  Get double on data upon purchase of 3.5GB data...          NA
# 1  Recharge of 100 mins and get WhatsApp Weekly Plan          NA
# 2  Get double on data upon purchase of 3.5GB data...          NA
# 3  Recharge of 100 mins and get WhatsApp Weekly Plan          NA
# 4  Recharge of 100 mins and get WhatsApp Weekly Plan          NA
# 5  Recharge of 100 mins and get WhatsApp Weekly Plan          NA
# 6  Recharge of 100 mins and get WhatsApp Weekly Plan          NA
# 7  Get double on data upon purchase of 3.5GB data...          NA
# 8  Recharge of 100 mins and get WhatsApp Weekly Plan          NA
# 9  Get double on data upon purchase of 3.5GB data...          NA
#
#   OfferCat_Rank_Score Potential Candidature
# 0                  NA         Tough Targets
# 1                  NA      Inert Candidates
# 2                  NA      Inert Candidates
# 3                  NA         Tough Targets
# 4                  NA      Inert Candidates
# 5                  NA         Tough Targets
# 6                  NA         Tough Targets
# 7                  NA      Inert Candidates
# 8                  NA      Inert Candidates
# 9                  NA         Tough Targets
#
# [10 rows x 37 columns]
# Outputs dumped to Outputs/Customer_Acquisition/Acquisition_CDNA

# %% [markdown]
# ## Customer Activation

# %%
from BehavioralModels.CustomerActivation.activation_modular import Activation
ACT_CONFIG = config['DEFAULT']['ACT_CONFIG']

# %%
ACT = Activation(ACT_CONFIG)
ACT.process_activation_customers()
# Out:
# Customer Activation started...
# Reading input files for Activation...
# Computing Activation Customer Utilization...
# New Growth Customers:
#    pf_customer_id  OfferID  Usage_feature1  Usage_feature2  Usage_feature3  \
# 0           60000       17               0              78              36
# 1           60013       17             100              45              14
# 2           60032       17               0               0             100
# 3           60001       17               0               0               0
# 4           60003       17              71               0               0
#
#    Usage_feature4  Usage_feature5  Feature1  Feature2  Feature3  Feature4  \
# 0               0               0       892       196       920       420
# 1               0               0       892       196       920       420
# 2              51              66       892       196       920       420
# 3               0              33       892       196       920       420
# 4              96               0       892       196       920       420
#
#    Feature5  utilization_feature1  utilization_feature2  utilization_feature3  \
# 0       123              0.000000              0.397959              0.039130
# 1       123              0.112108              0.229592              0.015217
# 2       123              0.000000              0.000000              0.108696
# 3       123              0.000000              0.000000              0.000000
# 4       123              0.079596              0.000000              0.000000
#
#    utilization_feature4  utilization_feature5  max_util  is_growth
# 0              0.000000              0.000000  0.397959          1
# 1              0.000000              0.000000  0.229592          1
# 2              0.121429              0.536585  0.536585          1
# 3              0.000000              0.268293  0.268293          1
# 4              0.228571              0.000000  0.228571          1
# Updated activation Customers:
#     pf_customer_id  OfferID  Usage_feature1  Usage_feature2  Usage_feature3  \
# 8            60010       17               0               0              10
# 20           60016       17               0               0               0
# 22           60011       17               0               0               0
# 26           60028       17               0               0               0
#
#     Usage_feature4  Usage_feature5  Feature1  Feature2  Feature3  Feature4  \
# 8                0               0       892       196       920       420
# 20               0               0       892       196       920       420
# 22              11               0       892       196       920       420
# 26               0               0       892       196       920       420
#
#     Feature5  utilization_feature1  utilization_feature2  \
# 8        123                   0.0                   0.0
# 20       123                   0.0                   0.0
# 22       123                   0.0                   0.0
# 26       123                   0.0                   0.0
#
#     utilization_feature3  utilization_feature4  utilization_feature5  \
# 8                0.01087               0.00000                   0.0
# 20               0.00000               0.00000                   0.0
# 22               0.00000               0.02619                   0.0
# 26               0.00000               0.00000                   0.0
#
#     max_util  is_growth
# 8    0.01087          0
# 20   0.00000          0
# 22   0.02619          0
# 26   0.00000          0
# Calculating Customers with high tenure and no usage...
# High Tenure without usage customers:
#          Date  Lead_ID  Cust_ID  Offer_ID  Offer_Sent_Time  Ch1_Response  \
# 0  17-04-2022       40    60016        15                2             1
#
#    Ch2_Response  Ch3_Response Acquisition_Status Acquisition_Channel  \
# 0             0             0           Acquired           Channel_1
#
#   Potential Candidature  Clusters  1st_best  tenure
# 0       Dormant Recruit         1        17      19
# Updated Activation Customers:
#            Date  Lead_ID  Cust_ID  Offer_ID  Offer_Sent_Time  Ch1_Response  \
# 8   07-04-2022       49    60010         5                4             0
# 20  17-04-2022       40    60016        15                2             1
# 22  11-04-2022        6    60011         8                6             0
# 26  03-05-2022       36    60028         9                3             1
#
#     Ch2_Response  Ch3_Response Acquisition_Status Acquisition_Channel  \
# 8              1             0           Acquired           Channel_2
# 20             0             0           Acquired           Channel_1
# 22             1             0           Acquired           Channel_2
# 26             0             0           Acquired           Channel_1
#
#    Potential Candidature  Clusters  1st_best  tenure
# 8        Dormant Recruit         2        17       2
# 20       Dormant Recruit         1        17      19
# 22       Dormant Recruit         1        17       2
# 26       Dormant Recruit         1        17      14
# New Growth Customers:
#      pf_customer_id  OfferID  Usage_feature1  Usage_feature2  Usage_feature3  \
# 0            60000       17               0              78              36
# 1            60013       17             100              45              14
# 2            60032       17               0               0             100
# 3            60001       17               0               0               0
# 4            60003       17              71               0               0
# 5            60005       17               0              79               0
# 6            60033       17              15              66               0
# 7            60007       17              56               0               0
# 9            60015       17               0              89              84
# 10           60018       17              88               0              60
#
#     Usage_feature4  Usage_feature5  Feature1  Feature2  Feature3  Feature4  \
# 0                0               0       892       196       920       420
# 1                0               0       892       196       920       420
# 2               51              66       892       196       920       420
# 3                0              33       892       196       920       420
# 4               96               0       892       196       920       420
# 5               88              50       892       196       920       420
# 6                0               0       892       196       920       420
# 7               79              68       892       196       920       420
# 9                0               0       892       196       920       420
# 10              16               0       892       196       920       420
#
#     Feature5  utilization_feature1  utilization_feature2  \
# 0        123              0.000000              0.397959
# 1        123              0.112108              0.229592
# 2        123              0.000000              0.000000
# 3        123              0.000000              0.000000
# 4        123              0.079596              0.000000
# 5        123              0.000000              0.403061
# 6        123              0.016816              0.336735
# 7        123              0.062780              0.000000
# 9        123              0.000000              0.454082
# 10       123              0.098655              0.000000
#
#     utilization_feature3  utilization_feature4  utilization_feature5  \
# 0               0.039130              0.000000              0.000000
# 1               0.015217              0.000000              0.000000
# 2               0.108696              0.121429              0.536585
# 3               0.000000              0.000000              0.268293
# 4               0.000000              0.228571              0.000000
# 5               0.000000              0.209524              0.406504
# 6               0.000000              0.000000              0.000000
# 7               0.000000              0.188095              0.552846
# 9               0.091304              0.000000              0.000000
# 10              0.065217              0.038095              0.000000
#
#     max_util  is_growth
# 0   0.397959          1
# 1   0.229592          1
# 2   0.536585          1
# 3   0.268293          1
# 4   0.228571          1
# 5   0.406504          1
# 6   0.336735          1
# 7   0.552846          1
# 9   0.454082          1
# 10  0.098655          1
# Customers with High Tenure but no Usage:
#           Date  Lead_ID  Cust_ID  Offer_ID  Offer_Sent_Time  Ch1_Response  \
# 0  17-04-2022       40    60016        15                2             1
#
#    Ch2_Response  Ch3_Response Acquisition_Status Acquisition_Channel  \
# 0             0             0           Acquired           Channel_1
#
#   Potential Candidature  Clusters  1st_best  tenure  updated_offer
# 0       Dormant Recruit         1        17      19             18
# Outputs saved at Outputs/CustomerActivation
