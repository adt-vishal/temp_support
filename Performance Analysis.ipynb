# %% [markdown]
# ### Performance Analysis

# %%
from PerformanceAnalysis.kpi import KPI
from PerformanceAnalysis.Testing import StatisticalTest
from PerformanceAnalysis.Anomaly_with_correlator import AnomalyDetection
from PerformanceAnalysis.PointAnomaly import PointAnomalyDetection

import configparser
config = configparser.ConfigParser()
config.read('config.ini')
PA_CONFIG = config['DEFAULT']['PA_CONFIG']

# %% [markdown]
# #### 1. Campaign KPIs

# %%
KPI_Report = KPI(PA_CONFIG)
KPI_Report.create_kpi_report()
# Out:
# Reading Config files and Input Schema...
# ...

# %% [markdown]
# #### 2. Anomaly Detection

# %%
Anomaly = AnomalyDetection(PA_CONFIG)
Anomaly.anomaly_detection()
# Out:
# Reading Config files and Input Schema...
# ...

# %% [markdown]
# #### 3. Point Anomaly Detection

# %%
Anomaly = PointAnomalyDetection(PA_CONFIG)
Anomaly.point_anomaly_detection()
# Out:
# Reading Config files and Input Schema...
# {'anomaly_input_path': 'Inputs', 'anomaly_output_path': 'Outputs', 'anomaly_input_filename': 'anomaly_test.csv', 'anomaly_output_filename': 'PointAnomaly', 'feature': ['Ch1_ResponseRate_HM_Mean', 'Ch2_ResponseRate_HM_Mean', 'Ch3_ResponseRate_HM_Mean'], 'datetime_col': 'date', 'segment_col': 'Segment', 'offerID_col': 'OfferID', 'year': 2019, 'month': 1, 'contamination': 'auto'}
#             Segment  OfferID  Ch1_ResponseRate_HM_Mean  \
# date
# 2019-01-01        1        1                      0.61
# 2019-02-01        1        1                      0.47
# 2019-03-01        1        1                      0.52
# 2019-04-01        1        1                      0.45
# 2019-05-01        1        1                      0.40
#
#             Ch2_ResponseRate_HM_Mean  Ch3_ResponseRate_HM_Mean
# date
# 2019-01-01                      0.22                      0.38
# 2019-02-01                      0.55                      0.01
# ...

# %% [markdown]
# #### 4. Statistical Testing

# %%
ST_Report = StatisticalTest(PA_CONFIG)
ST_Report.statistical_testing()
# Out:
# Reading Config files and Input Schema...
# ...
